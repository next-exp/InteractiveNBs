# %% [markdown]
# <font size="7">**NEW high-energy analysis**</font>
#
# <font size="4">This notebook demonstrates the main components of the high-energy analysis, it takes as input corrected energy at **Krypton scale** coming out from Esmeralda step in reconstruction, and performs several main steps in the following order:
# 1. Determine the correction for the z-effect by plotting energy  vs. Z and fitting the resulting 2D distribution in the region of interest.  The fit slope/intercept for each peak can be considered in deciding on the final correction factor $(m/b)$: $E \rightarrow E/(1 + (m/b)\Delta z)$
#
# 2. Fit the three peaks (Cs photopeak, $^{208}$Tl double-escape peak, and $^{208}$Tl photopeak) **AFTER** application of the z-correction to determine their means to be used in the calibration.
#
# 3. Perform the calibration.  Fit the peaks again to determine the energy resolution.</font>

# %%
# %matplotlib inline

import os
import textwrap
import math

import datetime as dt
import pandas as pd

import matplotlib        as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import MO, TU, WE, TH, FR, SA, SU

import numpy             as np
import tables            as tb

import invisible_cities.core.core_functions as coref
import invisible_cities.core.fit_functions  as fitf
import invisible_cities.reco.dst_functions  as dstf
import invisible_cities.reco.tbl_functions  as tbl
import invisible_cities.sierpe.blr          as blr

from   invisible_cities.icaro. hst_functions   import display_matrix
from   invisible_cities.database               import load_db

from   matplotlib                              import gridspec
from   matplotlib.patches                      import Ellipse
from   scipy.optimize                          import curve_fit
from   scipy.interpolate                       import interp1d
from   scipy                                   import stats

from   matplotlib.colors                       import SymLogNorm

# Formatting options
mpl.rcParams.update({'font.size': 18})
mpl.rcParams['image.cmap'] = 'Greys'
mpl.rcParams['patch.force_edgecolor'] = False
mpl.rcParams['patch.facecolor'] = 'gray'
hargs = {'histtype': 'stepfilled', 'edgecolor': 'black', 'facecolor': 'gray'}

# Options for saving plots
save_dir = "fig_highenergy"  # Directory to which figures will be stored.
save_ftype = "pdf"            # Figure extension ("pdf", "png", etc.)

if(not os.path.isdir(save_dir)):
    os.mkdir(save_dir)

# %% [markdown]
# -------------------------

# %% [markdown]
# # Section A: Load event information

# %%
# Get the data.
! wget https://www.dropbox.com/s/gf77oxotowxu65o/ntuple_combined_50_7430.h5
! wget https://www.dropbox.com/s/vcn3u4ggfszeprj/ntuple_combined_50_7431.h5
! wget https://www.dropbox.com/s/mbuaqo8za45nncq/ntuple_combined_50_7432.h5
! wget https://www.dropbox.com/s/nqe8rgkcdgj0bne/ntuple_combined_50_7433.h5
! wget https://www.dropbox.com/s/a6lmbb4l7p30kh4/ntuple_combined_50_7435.h5
# Out:
# --2019-10-11 18:58:08--  https://www.dropbox.com/s/gf77oxotowxu65o/ntuple_combined_50_7430.h5
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.68.1, 2620:100:6024:1::a27d:4401
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.68.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/gf77oxotowxu65o/ntuple_combined_50_7430.h5 [following]
# --2019-10-11 18:58:09--  https://www.dropbox.com/s/raw/gf77oxotowxu65o/ntuple_combined_50_7430.h5
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca0cfb7281f7a8099948149ad14.dl.dropboxusercontent.com/cd/0/inline/AqMARYfQvspw1Ixbr79u3hfp-ZeusVEKSN0E7JtiChqPszHC-bYVL_FUkatHi2e65dUoiBLDG_aYQYKmlKFLdjdF-bKb3ZOoYz9Dg_huih2hheijPLnY0q3YvVokOBh_M-4/file# [following]
# --2019-10-11 18:58:09--  https://uca0cfb7281f7a8099948149ad14.dl.dropboxusercontent.com/cd/0/inline/AqMARYfQvspw1Ixbr79u3hfp-ZeusVEKSN0E7JtiChqPszHC-bYVL_FUkatHi2e65dUoiBLDG_aYQYKmlKFLdjdF-bKb3ZOoYz9Dg_huih2hheijPLnY0q3YvVokOBh_M-4/file
# Resolving uca0cfb7281f7a8099948149ad14.dl.dropboxusercontent.com (uca0cfb7281f7a8099948149ad14.dl.dropboxusercontent.com)... 162.125.68.6, 2620:100:6024:6::a27d:4406
# Connecting to uca0cfb7281f7a8099948149ad14.dl.dropboxusercontent.com (uca0cfb7281f7a8099948149ad14.dl.dropboxusercontent.com)|162.125.68.6|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: /cd/0/inline2/AqOi4-2bIHGx3bNgyS0YksNpyTehXWGVfC6bzQG358eVb1iGVBnKQleG5jApNDj_L3t4OUCeR_QGjbwu3PxnHtk3ClWo5zQ0U2pFPMkzUTR_2SeZO5GCJXIQhIuzkbvdmZHSsczbc7ubK3gcjFUXMtgAYk0UP-fjAv5WZTko8Yc6AI4K3dzj4s6dYKIamCYSbSntvtednSWz2Md_5QSVz6C6dCNwNfe3y6uQZuI6_rFuKzJ4dmJZCkNR7HODRRNKP1Q8VraiQzWCc0fZaB_GHxd68qQLC5k4f27DmybFx1A0XBqF1yDOU9OyLQcPbE2vf_G98xqOud4QkJ0X0LmDXRBdP7tt0hkSK0YRDtdkRnIJdQ/file [following]
# --2019-10-11 18:58:10--  https://uca0cfb7281f7a8099948149ad14.dl.dropboxusercontent.com/cd/0/inline2/AqOi4-2bIHGx3bNgyS0YksNpyTehXWGVfC6bzQG358eVb1iGVBnKQleG5jApNDj_L3t4OUCeR_QGjbwu3PxnHtk3ClWo5zQ0U2pFPMkzUTR_2SeZO5GCJXIQhIuzkbvdmZHSsczbc7ubK3gcjFUXMtgAYk0UP-fjAv5WZTko8Yc6AI4K3dzj4s6dYKIamCYSbSntvtednSWz2Md_5QSVz6C6dCNwNfe3y6uQZuI6_rFuKzJ4dmJZCkNR7HODRRNKP1Q8VraiQzWCc0fZaB_GHxd68qQLC5k4f27DmybFx1A0XBqF1yDOU9OyLQcPbE2vf_G98xqOud4QkJ0X0LmDXRBdP7tt0hkSK0YRDtdkRnIJdQ/file
# Reusing existing connection to uca0cfb7281f7a8099948149ad14.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 55809377 (53M) [application/octet-stream]
# Saving to: ‘ntuple_combined_50_7430.h5.4’
#
# ntuple_combined_50_ 100%[===================>]  53,22M  21,1MB/s    in 2,5s
#
# 2019-10-11 18:58:14 (21,1 MB/s) - ‘ntuple_combined_50_7430.h5.4’ saved [55809377/55809377]
#
# --2019-10-11 18:58:14--  https://www.dropbox.com/s/vcn3u4ggfszeprj/ntuple_combined_50_7431.h5
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.68.1, 2620:100:6024:1::a27d:4401
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.68.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/vcn3u4ggfszeprj/ntuple_combined_50_7431.h5 [following]
# --2019-10-11 18:58:14--  https://www.dropbox.com/s/raw/vcn3u4ggfszeprj/ntuple_combined_50_7431.h5
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc44c41717881b1e959ae926347e.dl.dropboxusercontent.com/cd/0/inline/AqOyKZ_tnuQDPTF32Sq1-Ua3pMXwYQRzgh8co27r3ru4lHnCq39tL_Iv9LP1kMS1A7w6Cb-02KLPVeur6b28O3zWAQXBQjR-aUzpLSZT4nX9NtGug6rofWPi3-KO9gn33O4/file# [following]
# --2019-10-11 18:58:15--  https://uc44c41717881b1e959ae926347e.dl.dropboxusercontent.com/cd/0/inline/AqOyKZ_tnuQDPTF32Sq1-Ua3pMXwYQRzgh8co27r3ru4lHnCq39tL_Iv9LP1kMS1A7w6Cb-02KLPVeur6b28O3zWAQXBQjR-aUzpLSZT4nX9NtGug6rofWPi3-KO9gn33O4/file
# Resolving uc44c41717881b1e959ae926347e.dl.dropboxusercontent.com (uc44c41717881b1e959ae926347e.dl.dropboxusercontent.com)... 162.125.68.6, 2620:100:6024:6::a27d:4406
# Connecting to uc44c41717881b1e959ae926347e.dl.dropboxusercontent.com (uc44c41717881b1e959ae926347e.dl.dropboxusercontent.com)|162.125.68.6|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: /cd/0/inline2/AqP6VBCz-lD5oCGHWgFbyGwT-SNifzjAO0YmQZhxQx-r9Ii-yNGL4zisxi2Ql8sygJ2lM6q8oHI_9Oy4lRFYB7tIaOY31CcHfEx_oJKtFlSv4JC3tPlOYjCQJxN97yfxyZsKZa3KKH36kRvqZ7Ck2qhbcEObuTN1WtdTkzYUnw9eh5N7u_2Aj9_AoX5OYCc65RyaXnLGIEvWwm5hXjvWnq2Iyu-MnRLxB2epQUr4U-uGH46SuBdADIwq_oCnxxNW1_Nm9dlx82C4z7cU78tZX9tQezfm0MdFfAi8mxFCLdhKC7ziQwQNr1ya_MgRANMVJl_On97yDJMP09fkzp4xDbLkB77u-dZe3j8Rl55nSuovXQ/file [following]
# --2019-10-11 18:58:16--  https://uc44c41717881b1e959ae926347e.dl.dropboxusercontent.com/cd/0/inline2/AqP6VBCz-lD5oCGHWgFbyGwT-SNifzjAO0YmQZhxQx-r9Ii-yNGL4zisxi2Ql8sygJ2lM6q8oHI_9Oy4lRFYB7tIaOY31CcHfEx_oJKtFlSv4JC3tPlOYjCQJxN97yfxyZsKZa3KKH36kRvqZ7Ck2qhbcEObuTN1WtdTkzYUnw9eh5N7u_2Aj9_AoX5OYCc65RyaXnLGIEvWwm5hXjvWnq2Iyu-MnRLxB2epQUr4U-uGH46SuBdADIwq_oCnxxNW1_Nm9dlx82C4z7cU78tZX9tQezfm0MdFfAi8mxFCLdhKC7ziQwQNr1ya_MgRANMVJl_On97yDJMP09fkzp4xDbLkB77u-dZe3j8Rl55nSuovXQ/file
# Reusing existing connection to uc44c41717881b1e959ae926347e.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 66441158 (63M) [application/octet-stream]
# Saving to: ‘ntuple_combined_50_7431.h5.4’
#
# ntuple_combined_50_ 100%[===================>]  63,36M  21,8MB/s    in 2,9s
#
# 2019-10-11 18:58:20 (21,8 MB/s) - ‘ntuple_combined_50_7431.h5.4’ saved [66441158/66441158]
#
# --2019-10-11 18:58:20--  https://www.dropbox.com/s/mbuaqo8za45nncq/ntuple_combined_50_7432.h5
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.68.1, 2620:100:6024:1::a27d:4401
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.68.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/mbuaqo8za45nncq/ntuple_combined_50_7432.h5 [following]
# --2019-10-11 18:58:20--  https://www.dropbox.com/s/raw/mbuaqo8za45nncq/ntuple_combined_50_7432.h5
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc810b72382c6b0c6310ccfcc99f.dl.dropboxusercontent.com/cd/0/inline/AqPrtOXZhUUDHAMKtlHjhFWZf_nA_s2C-Np0dEvUHMM5v4n4sb75sfMGOiJun1WE5_-ahoRux6qIIeRJOG5RozsHPxC2p0QQS5sMu-vZJ6apl3UAvArOegYJvDu_V3om9O8/file# [following]
# --2019-10-11 18:58:21--  https://uc810b72382c6b0c6310ccfcc99f.dl.dropboxusercontent.com/cd/0/inline/AqPrtOXZhUUDHAMKtlHjhFWZf_nA_s2C-Np0dEvUHMM5v4n4sb75sfMGOiJun1WE5_-ahoRux6qIIeRJOG5RozsHPxC2p0QQS5sMu-vZJ6apl3UAvArOegYJvDu_V3om9O8/file
# Resolving uc810b72382c6b0c6310ccfcc99f.dl.dropboxusercontent.com (uc810b72382c6b0c6310ccfcc99f.dl.dropboxusercontent.com)... 162.125.68.6, 2620:100:6024:6::a27d:4406
# Connecting to uc810b72382c6b0c6310ccfcc99f.dl.dropboxusercontent.com (uc810b72382c6b0c6310ccfcc99f.dl.dropboxusercontent.com)|162.125.68.6|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: /cd/0/inline2/AqOQgwMIQQ8wIMGwlLodiYs3g6G9xSefkPMyoaTMXn9fO3-kYo52-5wnfitwrqkiBmDU3sso7nL6Az36lVpLvbqIs-rfgenX6Oj75Mtm92yPqhV3l6EfPYkDawkeyaP6q4sLoa8I3Ng-qBA2FjaxUTLwCmMJw3MqNmbTX35Us5nPeQWKehY2EXVvQ3Ps0A_-f0uVAAzMM4XEPOLtsmgvlA9mSmtHMbFLKty6FA2FddO1gUL97GEKQn-Piw3ZUWZj08hqy386NQEMaoGbB_gn3h97UWb15MUpKvyQrzOsvhhIlxPLcEbUH-V2M3HxZOFTypFcUpT_ke1Bv1KljsQ9L3pJqwGmoStbHoizkEeK-zUcSA/file [following]
# --2019-10-11 18:58:22--  https://uc810b72382c6b0c6310ccfcc99f.dl.dropboxusercontent.com/cd/0/inline2/AqOQgwMIQQ8wIMGwlLodiYs3g6G9xSefkPMyoaTMXn9fO3-kYo52-5wnfitwrqkiBmDU3sso7nL6Az36lVpLvbqIs-rfgenX6Oj75Mtm92yPqhV3l6EfPYkDawkeyaP6q4sLoa8I3Ng-qBA2FjaxUTLwCmMJw3MqNmbTX35Us5nPeQWKehY2EXVvQ3Ps0A_-f0uVAAzMM4XEPOLtsmgvlA9mSmtHMbFLKty6FA2FddO1gUL97GEKQn-Piw3ZUWZj08hqy386NQEMaoGbB_gn3h97UWb15MUpKvyQrzOsvhhIlxPLcEbUH-V2M3HxZOFTypFcUpT_ke1Bv1KljsQ9L3pJqwGmoStbHoizkEeK-zUcSA/file
# Reusing existing connection to uc810b72382c6b0c6310ccfcc99f.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 67013853 (64M) [application/octet-stream]
# Saving to: ‘ntuple_combined_50_7432.h5.4’
#
# ntuple_combined_50_ 100%[===================>]  63,91M   602KB/s    in 1m 41s
#
# 2019-10-11 19:00:04 (649 KB/s) - ‘ntuple_combined_50_7432.h5.4’ saved [67013853/67013853]
#
# --2019-10-11 19:00:04--  https://www.dropbox.com/s/nqe8rgkcdgj0bne/ntuple_combined_50_7433.h5
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.68.1, 2620:100:6024:1::a27d:4401
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.68.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/nqe8rgkcdgj0bne/ntuple_combined_50_7433.h5 [following]
# --2019-10-11 19:00:04--  https://www.dropbox.com/s/raw/nqe8rgkcdgj0bne/ntuple_combined_50_7433.h5
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc895f58486df32da8d94b72b479.dl.dropboxusercontent.com/cd/0/inline/AqPQP31Sj-OOSrO7_EfX_rDzO4-e1ducFoOxRXuLO16ocO5J598t5xoRjpxsMAkhteGvdSVJ8WQEFbPpBlCdiUhg-R69cnvqb6Rd5FQFCP-xvmrdjt_psKRVQOeWA5St980/file# [following]
# --2019-10-11 19:00:05--  https://uc895f58486df32da8d94b72b479.dl.dropboxusercontent.com/cd/0/inline/AqPQP31Sj-OOSrO7_EfX_rDzO4-e1ducFoOxRXuLO16ocO5J598t5xoRjpxsMAkhteGvdSVJ8WQEFbPpBlCdiUhg-R69cnvqb6Rd5FQFCP-xvmrdjt_psKRVQOeWA5St980/file
# Resolving uc895f58486df32da8d94b72b479.dl.dropboxusercontent.com (uc895f58486df32da8d94b72b479.dl.dropboxusercontent.com)... 162.125.68.6, 2620:100:6024:6::a27d:4406
# Connecting to uc895f58486df32da8d94b72b479.dl.dropboxusercontent.com (uc895f58486df32da8d94b72b479.dl.dropboxusercontent.com)|162.125.68.6|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: /cd/0/inline2/AqNSYjaqCtuHI30ekBOiUcBc3lk0vSeXG87hth9W_dQrtfKmKKY0iLQAQolRwc9862Jd2-AUHMUOhsBnJHLm3GBGiZM1xuy2HVH3TH3aFC_tbAcLq0U2Y4EwCWUUaRCGMsphSyfNNQAjri_DxF2vrM_VpTWWqtrKChi0U8LEg46jEUYw9rE3gk-FMD8Neojv0OIR0QNOV3iGVkTxejUXN6F32bVlYLu72sYTOHixaY5IScPMLwXdPE-vlqvtuN8tbDSlzntnsm-cqWgSIkqN3KsxbBTRF47OSyVpXJrgtVOOLKH1rx-53rbci-vEBPIaUstOVijW0q68ERXX5F1LUmxvebPzZpmaJb_fMazxR0vXbw/file [following]
# --2019-10-11 19:00:06--  https://uc895f58486df32da8d94b72b479.dl.dropboxusercontent.com/cd/0/inline2/AqNSYjaqCtuHI30ekBOiUcBc3lk0vSeXG87hth9W_dQrtfKmKKY0iLQAQolRwc9862Jd2-AUHMUOhsBnJHLm3GBGiZM1xuy2HVH3TH3aFC_tbAcLq0U2Y4EwCWUUaRCGMsphSyfNNQAjri_DxF2vrM_VpTWWqtrKChi0U8LEg46jEUYw9rE3gk-FMD8Neojv0OIR0QNOV3iGVkTxejUXN6F32bVlYLu72sYTOHixaY5IScPMLwXdPE-vlqvtuN8tbDSlzntnsm-cqWgSIkqN3KsxbBTRF47OSyVpXJrgtVOOLKH1rx-53rbci-vEBPIaUstOVijW0q68ERXX5F1LUmxvebPzZpmaJb_fMazxR0vXbw/file
# Reusing existing connection to uc895f58486df32da8d94b72b479.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 65195023 (62M) [application/octet-stream]
# Saving to: ‘ntuple_combined_50_7433.h5.4’
#
# ntuple_combined_50_ 100%[===================>]  62,17M  19,5MB/s    in 3,2s
#
# 2019-10-11 19:00:10 (19,5 MB/s) - ‘ntuple_combined_50_7433.h5.4’ saved [65195023/65195023]
#
# --2019-10-11 19:00:10--  https://www.dropbox.com/s/a6lmbb4l7p30kh4/ntuple_combined_50_7435.h5
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.68.1, 2620:100:6024:1::a27d:4401
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.68.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/a6lmbb4l7p30kh4/ntuple_combined_50_7435.h5 [following]
# --2019-10-11 19:00:11--  https://www.dropbox.com/s/raw/a6lmbb4l7p30kh4/ntuple_combined_50_7435.h5
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc0bc81dad628df1d65eeded8c17.dl.dropboxusercontent.com/cd/0/inline/AqPom4VZiNvfU-8LyxkcLU6yNP38q8szrm_GMuFIsu32-2cDhTGpiSVIvGh2JwuSWUQb_1cRmFjLI7uQlJd-sNnTlpMWn8oORs-objFxcgWn3h9XXpUftVVJafpvbNPBSkQ/file# [following]
# --2019-10-11 19:00:11--  https://uc0bc81dad628df1d65eeded8c17.dl.dropboxusercontent.com/cd/0/inline/AqPom4VZiNvfU-8LyxkcLU6yNP38q8szrm_GMuFIsu32-2cDhTGpiSVIvGh2JwuSWUQb_1cRmFjLI7uQlJd-sNnTlpMWn8oORs-objFxcgWn3h9XXpUftVVJafpvbNPBSkQ/file
# Resolving uc0bc81dad628df1d65eeded8c17.dl.dropboxusercontent.com (uc0bc81dad628df1d65eeded8c17.dl.dropboxusercontent.com)... 162.125.68.6, 2620:100:6024:6::a27d:4406
# Connecting to uc0bc81dad628df1d65eeded8c17.dl.dropboxusercontent.com (uc0bc81dad628df1d65eeded8c17.dl.dropboxusercontent.com)|162.125.68.6|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: /cd/0/inline2/AqPrL-F-0uRzsNTmB7__JT1p5SV6EXvg6F-CRogYdfsHibc8g9WuQlFPMQJAdE0WQ5wluENLDwFplTvwByyQMRvQgux528hFxitKDqmxAdwhA1CeZrb4dr5zJLlT5TxF5u3MuPezXn-Bz5ms5rQQT3d-f9viTpaiHLqUBvz4-rDu5qzqZjwIF3LuJPKwZwfDoSCWukY1kl7PHiTMJay4Q5VYA4P2ZWHHC8VqM22qBQ9VbZVagkZhvNCrYSt_nJXtd-Jbno42x-QgMIH5hkyfvOrLR8WoH8SISzEawD6ZBVn8hOa8UHGaq5AcPCIMj_KdYDiVxD3vwHJ102acPqnv8Y569EHV3bNGcPlwf7aNTOpg8w/file [following]
# --2019-10-11 19:00:13--  https://uc0bc81dad628df1d65eeded8c17.dl.dropboxusercontent.com/cd/0/inline2/AqPrL-F-0uRzsNTmB7__JT1p5SV6EXvg6F-CRogYdfsHibc8g9WuQlFPMQJAdE0WQ5wluENLDwFplTvwByyQMRvQgux528hFxitKDqmxAdwhA1CeZrb4dr5zJLlT5TxF5u3MuPezXn-Bz5ms5rQQT3d-f9viTpaiHLqUBvz4-rDu5qzqZjwIF3LuJPKwZwfDoSCWukY1kl7PHiTMJay4Q5VYA4P2ZWHHC8VqM22qBQ9VbZVagkZhvNCrYSt_nJXtd-Jbno42x-QgMIH5hkyfvOrLR8WoH8SISzEawD6ZBVn8hOa8UHGaq5AcPCIMj_KdYDiVxD3vwHJ102acPqnv8Y569EHV3bNGcPlwf7aNTOpg8w/file
# Reusing existing connection to uc0bc81dad628df1d65eeded8c17.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 65375655 (62M) [application/octet-stream]
# Saving to: ‘ntuple_combined_50_7435.h5.4’
#
# ntuple_combined_50_ 100%[===================>]  62,35M  14,4MB/s    in 4,3s
#
# 2019-10-11 19:00:19 (14,4 MB/s) - ‘ntuple_combined_50_7435.h5.4’ saved [65375655/65375655]

# %% [markdown]
# ## A.1: (not necessary for interactive notebook) Combine information from various Esmeralda files into a single file
# Note that this only needs to be run once for a single run.

# %% [markdown]
# def combine_esmeralda_files(esmeralda_dir,combined_file):
#
#     # Obtain a sorted list of the files to combine.
#     files = glob(esmeralda_dir + '/ntuple_*.h5')
#     files = sorted(files, key=lambda s: int(s.split('.')[-2].split('_')[-1]))
#
#     # Open the final tables file.
#     fcombined = tables.open_file(out_file, "w", filters=tables.Filters(complib="blosc", complevel=9))
#     group_PAOLINA = fcombined.create_group(fcombined.root, "PAOLINA")
#
#     # Process the first file.
#     f1 = tables.open_file(files[0], 'r')
#     print("-- Adding file {0}".format(files[0]));
#     paolina_combined = f1.copy_node('/PAOLINA', name='Summary', newparent=group_PAOLINA)
#     f1.close()
#
#     # Process the remaining files.
#     for fn in files[1:]:
#
#         # Open the next file and extract the elements.
#         fn = tables.open_file(fn, 'r')
#         print("-- Adding file {0}".format(fn));
#         if("/PAOLINA/Summary" in fn):
#             paolina_n = fn.root.PAOLINA.Summary
#             paolina_combined.append(paolina_n.read())
#         else:
#             print(" --> Skipping file due to no table found")
#         fn.close()
#         fcombined.flush()
#
#     # Close the combined file.
#     print("Saving combined file {0}".format(combined_file))
#     fcombined.close()

# %% [markdown]
# combine_esmeralda_files(esmeralda_dir = "/analysis/{}/hdf5/ntuple/trigger{}".format(run,trigger_num),
#                         out_file = "ntuple_combined_{}.h5".format(out_dir,run))

# %% [markdown]
# ## A.2: Load the information from combined files
#
# The information from the Esmeralda step from each of the combined files is loaded into numpy arrays.  The names of the files to be combined are specified below.
#
# The file information will be loaded into numpy arrays as follows:
#
# `A_evtnum`      -- event number<br>
# `A_time`        -- timestamp<br>
# `A_eblob1`      -- energy of blob1 (most energetic) as obtained from Paolina analysis<br>
# `A_eblob2`      -- energy of blob2 (least energetic) as obtained from Paolina analysis<br>
# `A_emtrk`       -- energy of 10 most energetic Paolina tracks in the event<br>
# `A_xmtrk`       -- average reconstructed $x$-coordinate of 10 most energetic Paolina tracks in the event<br>
# `A_ymtrk`       -- average reconstructed $y$-coordinate of 10 most energetic Paolina tracks in the event<br>
# `A_zmtrk`       -- average reconstructed $z$-coordinate of 10 most energetic Paolina tracks in the event<br>
# `A_ntrks`       -- number of tracks in the event<br>
# `A_lmtrk`       -- length of most energetic Paolina track in event<br>
# `A_nvox`        -- number of voxels in the event<br>
# `A_nhits`       -- number of hits in the event<br>
# `A_Ec`          -- fully corrected energy (lifetime by hit + $(x,y)$ by hit)<br>
# `A_Eczlen`      -- fully corrected energy + z-length correction<br>
# `A_E0`          -- uncorrected energy<br>
# `A_xavg`        -- average reconstructed $x$-coordinate of event<br>
# `A_yavg`        -- average reconstructed $y$-coordinate of event<br>
# `A_zavg`        -- average reconstructed $z$-coordinate of event<br>
# `A_ravg`        -- average $r = \sqrt{x^2 + y^2}$ of event<br>
# `A_xmin`        -- minimum reconstructed $x$-coordinate of event<br>
# `A_ymin`        -- minimum reconstructed $y$-coordinate of event<br>
# `A_zmin`        -- minimum reconstructed $z$-coordinate of event<br>
# `A_xmax`        -- maximum reconstructed $x$-coordinate of event<br>
# `A_ymax`        -- maximum reconstructed $y$-coordinate of event<br>
# `A_zmax`        -- maximum reconstructed $z$-coordinate of event<br>
# `A_rmin`        -- minimum value of $r = \sqrt{x^2 + y^2}$ over all hits in event<br>
# `A_rmax`        -- maximum value of $r = \sqrt{x^2 + y^2}$ over all hits in event<br>

# %%
# Names of the combined files, each containing the information from the Esmeralda step for all events in a single run.
evtfnames   = ["ntuple_combined_50_7430.h5",
                "ntuple_combined_50_7431.h5",
                "ntuple_combined_50_7432.h5",
                "ntuple_combined_50_7433.h5",
                "ntuple_combined_50_7435.h5"]

# %%
A_evtnum = []; A_time = []; A_ES1 = []
A_eblob1 = []; A_eblob2 = []; A_emtrk = []; A_etrks = []; A_xtrks = []; A_ytrks = []; A_ztrks = []
A_ntrks = []; A_lmtrk = []; A_nvox = []; A_nhits = []
A_Ec = []; A_Eczlen = []; A_E0 = []; A_Echead = []; A_Ectail = []
A_xavg = []; A_yavg = []; A_zavg = []; A_ravg = []
A_xmin = []; A_ymin = []; A_zmin = []
A_xmax = []; A_ymax = []; A_zmax = []
A_rmin = []; A_rmax = []
for ii,fname in enumerate(evtfnames):
 
    print("Adding file {} ...".format(fname))
    ftbl = tb.open_file(fname, 'r')
    fn = ftbl.root.PAOLINA.Summary[:]
    
    A_evtnum = np.concatenate((A_evtnum,fn['event']))
    A_time   = np.concatenate((A_time,fn['time']))
    A_ES1    = np.concatenate((A_ES1,fn['S1e']))
    A_ntrks  = np.concatenate((A_ntrks,fn['ntrks']))
    A_nhits  = np.concatenate((A_nhits,fn['nhits']))
    A_Ec     = np.concatenate((A_Ec,fn['S2ec']))
    A_E0     = np.concatenate((A_E0,fn['S2e0']))
    A_xavg   = np.concatenate((A_xavg,fn['x_avg']))
    A_yavg   = np.concatenate((A_yavg,fn['y_avg']))
    A_zavg   = np.concatenate((A_zavg,fn['z_avg']))
    A_ravg   = np.concatenate((A_ravg,fn['r_avg']))
    A_xmin   = np.concatenate((A_xmin,fn['x_min']))
    A_ymin   = np.concatenate((A_ymin,fn['y_min']))
    A_zmin   = np.concatenate((A_zmin,fn['z_min']))
    A_xmax   = np.concatenate((A_xmax,fn['x_max']))
    A_ymax   = np.concatenate((A_ymax,fn['y_max']))
    A_zmax   = np.concatenate((A_zmax,fn['z_max']))
    A_rmin   = np.concatenate((A_rmin,fn['r_min']))
    A_rmax   = np.concatenate((A_rmax,fn['r_max']))


print("{} total events".format(len(A_evtnum)))
# Out:
# Adding file ntuple_combined_50_7430.h5 ...
# Adding file ntuple_combined_50_7431.h5 ...
# Adding file ntuple_combined_50_7432.h5 ...
# Adding file ntuple_combined_50_7433.h5 ...
# Adding file ntuple_combined_50_7435.h5 ...
# 3452757 total events

# %% [markdown]
# ## A.3: Definition of cuts and key quantities

# %%
# Key variables in constructing cuts.
cwide_zmin = 50; cwide_zmax = 500
cwide_rmax = 180
ctight_zmin = 150; ctight_zmax = 300
ctight_rmax = 150

# ------------------------------------------------------------------------------------------
# Pre-defined cuts
C_basic       = (A_E0 > 0) & (A_Ec > 0) & (A_zavg < 580)
C_wide        = C_basic & (A_zmin > cwide_zmin) & (A_zmax < cwide_zmax) & (A_rmax < cwide_rmax)
C_tight       = C_basic & (A_zmin > ctight_zmin) & (A_zmax < ctight_zmax) & (A_rmax < ctight_rmax)
C_tfiducial   = (abs(A_xmax) < 100) & (abs(A_ymax) < 100) & (abs(A_xmin) < 100) & (abs(A_ymin) < 100) & (A_zavg > 50) & (A_zavg < 150)

# Tabulated peak energies (in keV)
E_xKalpha = (29.112*0.00261 + 29.461*25.6 + 29.782*47.4)/(0.00261 + 25.6 + 47.4)
E_xKbeta  = (33.562*4.35 + 33.624*8.40 + 33.881*0.085 + 34.419*2.54 + 34.496*0.492)/(4.35 + 8.40 + 0.085 + 2.54 + 0.492)
E_Kr      = 41.543
E_238     = 238.632
E_511     = 511
E_583     = 583.191
E_Cs      = 661.657
E_descape = 1592.535
E_Tl      = 2614.533
E_0vbb    = 2458 
print("""
E_xKalpha = {}
E_xKbeta = {}
E_Kr = {}
E_238 = {}
E_511 = {}
E_583 = {}
E_Cs = {}
E_descape = {}
E_Tl = {}
""".format(E_xKalpha,E_xKbeta,E_Kr,E_238,E_511,E_583,E_Cs,E_descape,E_Tl))

# Tabulated peak uncertainties.
err_E_Cs = 0.07
err_E_descape = 0.12
err_E_Tl = 0.3
# Out:
# E_xKalpha = 29.669410207662434
# E_xKbeta = 33.76268210751875
# E_Kr = 41.543
# E_238 = 238.632
# E_511 = 511
# E_583 = 583.191
# E_Cs = 661.657
# E_descape = 1592.535
# E_Tl = 2614.533

# %% [markdown]
# --------------------------

# %% [markdown]
# # Section B: The z-effect

# %% [markdown]
# ## B.1: Function definitions

# %%
# A linear function mx + b
def flinear(x, m, b):
    return m*x + b

# Plot the energy vs. z-length.
def plot_E_vs_zlength(L_zlen, L_Ecplot, cuts_base, plt_rng_zlow, plt_rng_zhigh, plt_rng_Elow, plt_rng_Ehigh, nbins_E, nbins_z, mbound, b0, b1, plt_corrected = False):
    
    # Construct the cuts including the range in (z,E) space to be examined.
    cuts_bounds = (L_Ecplot > L_zlen*mbound + b0) & (L_Ecplot < L_zlen*mbound + b1)
    cuts_range = cuts_base & (L_zlen > plt_rng_zlow) & (L_zlen < plt_rng_zhigh) & (L_Ecplot > plt_rng_Elow) & (L_Ecplot < plt_rng_Ehigh)
    cuts_all = cuts_range & cuts_bounds
    
    # Assume an approximate 1% FWHM sigma on the energy measurements.
    esigma = 1.0*np.mean(L_Ecplot[cuts_all])/235
    
    # Perform the linear fit and extract the parameters.
    p_fit, V_fit = curve_fit(flinear, L_zlen[cuts_all], L_Ecplot[cuts_all], sigma=np.ones(len(L_zlen[cuts_all]))*esigma)
    m = p_fit[0]
    b = p_fit[1]
    var_m = V_fit[0][0]
    var_b = V_fit[1][1]
    var_mb = V_fit[0][1]
    xfit = np.arange(plt_rng_zlow, plt_rng_zhigh, (plt_rng_zhigh-plt_rng_zlow)/100)
    polyfit = np.poly1d([m, b])
    mb_err = (var_m/b**2 + m**2*var_b/b**4 - m*var_mb/b**3)**0.5
    print("Slope for correction {} +/- {}; intercept: {} +/- {}".format(m, var_m**0.5, b, var_b**0.5))
    print("Uncertainty in m/b = {}".format(mb_err))
    
    # Construct the boundary polynomials.
    polyfit_b0 = np.poly1d([mbound, b0])
    polyfit_b1 = np.poly1d([mbound, b1])
    
    # Create the plot.
    fig = plt.figure()
    fig.set_figheight(6.0)
    fig.set_figwidth(16.0)
    
    ax1 = fig.add_subplot(121)
    h, x, y = np.histogram2d(-L_Ecplot[cuts_range], L_zlen[cuts_range], bins=[nbins_E, nbins_z], range=[[-plt_rng_Ehigh,-plt_rng_Elow],[plt_rng_zlow,plt_rng_zhigh]])
    plt.imshow(h, extent=[plt_rng_zlow,plt_rng_zhigh,plt_rng_Elow,plt_rng_Ehigh], interpolation = "none", cmap='jet', aspect=(plt_rng_zhigh-plt_rng_zlow)/(plt_rng_Ehigh-plt_rng_Elow))
    plt.plot(xfit, polyfit_b0(xfit), '--', color='red')
    plt.plot(xfit, polyfit_b1(xfit), '--', color='red')
    plt.plot(xfit, polyfit(xfit), '-', color='red', linewidth=3, label="m/b = {:.2f} $\\times 10^{{-4}} \pm$ {:.2f} mm$^{{-1}}$".format(m/b*1e4,mb_err*1e4))
    plt.locator_params(axis='y', nbins=7)
    plt.legend(loc=1, fontsize=14)
    plt.colorbar()
    plt.ylim([plt_rng_Elow,plt_rng_Ehigh])
    plt.xlim([plt_rng_zlow,plt_rng_zhigh])
    plt.xlabel('z-length (mm)')
    plt.ylabel('E (Kr keV)')
    
    # Plot the corrected energy vs. z-length alongside the uncorrected plot.
    #  Note: this should only be enabled if the energies in L_Ecplot are uncorrected.
    
    E_rng = plt_rng_Ehigh - plt_rng_Elow
    ax2 = fig.add_subplot(122)
    h, x, y = np.histogram2d(-L_Ecplot[cuts_range]/(1+(m/b)*L_zlen[cuts_range]), L_zlen[cuts_range], bins=[nbins_E, nbins_z], range=[[-(b+E_rng/2),-(b-E_rng/2)],[plt_rng_zlow,plt_rng_zhigh]])
    plt.imshow(h, extent=[plt_rng_zlow,plt_rng_zhigh,b-E_rng/2,b+E_rng/2], interpolation = "none", cmap='jet', aspect=(plt_rng_zhigh-plt_rng_zlow)/E_rng)
    #plt.plot(xfit, polyfit_b0(xfit), '--', color='red')
    #plt.plot(xfit, polyfit_b1(xfit), '--', color='red')
    #plt.plot(xfit, polyfit(xfit), '-', color='red', linewidth=3, label="m/b = {:.2f} $\\times 10^{{-4}}$ mm$^{{-1}}$".format(m/b*1e4))
    #plt.legend(loc=1, fontsize=14)
    plt.colorbar()
    plt.title("Energy vs. z-length, CORRECTED")
    plt.ylim([b-E_rng/2,b+E_rng/2])
    plt.xlim([plt_rng_zlow,plt_rng_zhigh])
    plt.xlabel('z-length (mm)')
    plt.ylabel('E (kr keV)')
    return m, b

# %% [markdown]
# ## B.2: Z-effect for each peak

# %%
A_zlen = A_zmax - A_zmin

# %%
# Cs peak
mbound = -0.0003
b0 = 0.675
b1 = 0.697
plt_rng_zlow = 8
plt_rng_zhigh = 32
plt_rng_Elow = 0.660
plt_rng_Ehigh = 0.700

cuts_base = C_wide & (A_ntrks == 1)
mCs, bCs = plot_E_vs_zlength(A_zlen, A_Ec, cuts_base, plt_rng_zlow, plt_rng_zhigh, plt_rng_Elow, plt_rng_Ehigh, 15, 10, mbound, b0, b1)
#plt.savefig("{}/CSTH_zwidth_fit_Cs.{}".format(save_dir,'png'), bbox_inches='tight')
# Out:
# Slope for correction -0.000247021098441469 +/- 3.905079872235254e-06; intercept: 0.6844042320371174 +/- 8.005901875825614e-05
# Uncertainty in m/b = 5.685684651890125e-06

# %%
# 208Tl double-escape peak
mbound = -0.0008
b0 = 1.67
b1 = 1.705
plt_rng_zlow = 15
plt_rng_zhigh = 80
plt_rng_Elow = 1.62
plt_rng_Ehigh = 1.70

cuts_base = C_wide & (A_ntrks == 1)
mDE, bDE =plot_E_vs_zlength(A_zlen, A_Ec, cuts_base, plt_rng_zlow, plt_rng_zhigh, plt_rng_Elow, plt_rng_Ehigh, 15, 15, mbound, b0, b1)
#plt.savefig("{}/CSTH_zwidth_fit_DE.{}".format(save_dir,'png'), bbox_inches='tight')
# Out:
# Slope for correction -0.0007004994905104584 +/- 5.481521859898367e-06; intercept: 1.683384363376401 +/- 0.0002581641945681223
# Uncertainty in m/b = 3.226301398177984e-06

# %%
# Tl photopeak
mbound = -0.0008
b0 = 2.73
b1 = 2.83
plt_rng_zlow = 30
plt_rng_zhigh = 180
plt_rng_Elow = 2.65
plt_rng_Ehigh = 2.78

cuts_base = C_wide & (A_ntrks == 1)
mTl, bTl = plot_E_vs_zlength(A_zlen, A_Ec, cuts_base, plt_rng_zlow, plt_rng_zhigh, plt_rng_Elow, plt_rng_Ehigh, 15, 15, mbound, b0, b1)
#plt.savefig("{}/CSTH_zwidth_fit_Tl.{}".format(save_dir,'png'), bbox_inches='tight')
# Out:
# Slope for correction -0.0006473198687748996 +/- 2.2548426558944757e-05; intercept: 2.7648105291508545 +/- 0.00207717573099542
# Uncertainty in m/b = 8.073706973425095e-06

# %%
Z_corr_factor = 1./3.*(mCs/bCs + mDE/bDE + mTl/bTl) #for actuall analysis is fixed to 2.76e-4 
A_Eczlcorr = A_Ec/(1 + Z_corr_factor*A_zlen)

# %% [markdown]
# # Section C: Energy peaks

# %% [markdown]
# ## C.1: Function definitions

# %%
# Return errors on resolution extrapolated to Qbb
def reso_errors(values,errors,epeak):
    _, mu, sigma = values
    _, err_mu, err_sigma = errors
    r = 235. * sigma/mu
    err_r = r*np.sqrt((err_sigma/sigma)**2 + (err_mu/mu)**2)
    return r, err_r, r * (epeak/2458)**0.5, err_r * (epeak/2458)**0.5

# Returns text output for Gaussian fit function
def gausstext_err(values,errors,chisq,epeak):
    r,err_r,rbb,err_rbb = reso_errors(values,errors,epeak)
    return textwrap.dedent("""
        $\mu$ = {:.5f} $\pm$ {:.5f}
        $\sigma$ = {:.5f} $\pm$ {:.5f}
        R (%) = {:.2f} $\pm$ {:.2f}
        $\chi^2$/N$_\mathrm{{dof}}$ = {:.2f}""".format(values[1],errors[1],values[2],errors[2],r,err_r,chisq))

def plt_spectrum(energies, ecuts, plt_rng_low, plt_rng_high, fit_rng_low, fit_rng_high, 
                  fit_gauss_A, fit_gauss_mu, fit_gauss_sigma, text_x, nbins, outfile_name):
    
    fig = plt.figure(1)
    fig.patch.set_alpha(0.0)
    fig.set_figheight(4.8)
    fig.set_figwidth(6.0)

    # Make the histogram.
    y0, x0, _ = plt.hist(energies[ecuts], nbins, range=[plt_rng_low, plt_rng_high], **hargs)

    # Gaussian fit
    x    = x0[:-1] + np.diff(x0) * 0.5
    sel  = coref.in_range(x, fit_rng_low, fit_rng_high)
    x, y, sig = x[sel], y0[sel], np.sqrt(y0[sel])
    f    = fitf.fit(lambda x, *args: fitf.gauss(x, *args[:3]) + fitf.polynom(x, *args[3:]), x, y, (fit_gauss_A, fit_gauss_mu, fit_gauss_sigma, 1, -1/fit_gauss_mu, -1/fit_gauss_mu**2), sigma=sig)
    plt.plot(x, f.fn(x), "r")
    plt.text(text_x, 4.2*max(y)/6, gausstext_err(f.values[0:3],f.errors[0:3],f.chi2,E_238),fontsize=14)
    plt.xlabel('E (keV)')
    plt.ylabel('Counts/bin')
    print("Fit parameters are (amp, mu, sigma, A, mean, x0)")
    print(f.values)
    print("Fit errors are (amp, mu, sigma)")
    print(f.errors)
    print("Fit p-value assuming obtained chi2 and 1 d.o.f. is {}".format(1-stats.chi2.cdf(f.chi2, 1)))
    
    # Save the plot to file.
    #plt.savefig("{}/{}.{}".format(save_dir, outfile_name, save_ftype), bbox_inches='tight')

    # Compute the statistical error.
    mu = f.values[1]
    sigma = f.values[2]
    s_mu = f.errors[1]
    s_sigma = f.errors[2]
    R = sigma/mu
    s_R = (s_sigma**2 + R**2*s_mu**2)**0.5/mu
    print("Fit range: ({},{})".format(fit_rng_low,fit_rng_high))
    print("Fit range from mu in sigma: ({},{})".format((fit_rng_low-mu)/sigma,(fit_rng_high-mu)/sigma))
    print("Resolution is {} +/- {}".format(235*R,235*s_R))
    print("Resolution at Qbb is {} +/- {}".format(235*R*(E_238/E_0vbb)**0.5,235*s_R*(E_238/E_0vbb)**0.5))
    
    # Return the fit result.
    return f
    
def plt_xyz_distributions(xavg, yavg, zavg, cuts_xyz, nxybins, nzbins, zmin, zmax, rmax, outfile_name):

    fig = plt.figure(2)
    fig.patch.set_alpha(0.0)
    fig.set_figheight(4.0)
    fig.set_figwidth(12.0)

    # x-y distribution
    ax1 = fig.add_subplot(121)
    h, x, y = np.histogram2d(-yavg[cuts_xyz], xavg[cuts_xyz], bins=[nxybins, nxybins], range=[[-215, 215], [-215, 215]])
    plt.imshow(h, extent=[x[0],x[-1],y[0],y[-1]], interpolation = "gaussian", cmap='jet')
    plt.colorbar()
    plt.xlabel("average x (mm)")
    plt.ylabel("average y (mm)")
    ctight_circle = plt.Circle((0, 0), rmax, color='gray', alpha=0.15)
    ctight_lcircle = plt.Circle((0, 0), rmax, facecolor='none', linestyle='solid', edgecolor='red',linewidth=2)
    plt.gca().add_artist(ctight_lcircle)

    # z distribution
    ax2 = fig.add_subplot(122)
    hz = plt.hist(zavg[cuts_xyz], bins=nzbins, range=[0,580], **hargs)
    plt.xlabel("average z (mm)")
    plt.axvline(zmin,linestyle='solid',color='red',linewidth=1.2)
    plt.axvline(zmax,linestyle='solid',color='red',linewidth=1.2)
    plt.axvspan(zmin,zmax,linestyle='solid',facecolor='gray',edgecolor='red',linewidth=1.2,alpha=0.05)

    #plt.savefig("{}/{}.{}".format(save_dir, outfile_name, save_ftype), bbox_inches='tight')

# %% [markdown]
# ## C.2: Full energy spectrum

# %%
cuts_fullspectrum = C_wide & (A_ntrks == 1)

fig = plt.figure(1)
fig.patch.set_alpha(0.0)
fig.set_figheight(4.0)
fig.set_figwidth(12.0)

y, x, _ = plt.hist(A_Eczlcorr[cuts_fullspectrum], 1000, range=[0.01,3.0], **hargs)
plt.xlabel('E (keV)')
plt.ylabel('Counts/bin')
plt.yscale('log')
plt.annotate('$^{137}$Cs photopeak', xy=(0.70, 10000),  xycoords='data',
                 xytext=(0.90, 12000), textcoords='data', fontsize=16,
                 arrowprops=dict(arrowstyle="-"))
plt.annotate('$^{208}$Tl e$^{+}$e$^{-}$ double-escape', xy=(1.69, 1500),  xycoords='data',
                 xytext=(1.9, 10000), textcoords='data', fontsize=16,
                 arrowprops=dict(arrowstyle="-"))
plt.annotate('$^{208}$Tl photopeak', xy=(2.7, 60),  xycoords='data',
                xytext=(2.0, 500), textcoords='data', fontsize=16,
                arrowprops=dict(arrowstyle="-"))

#plt.savefig("{}/CSTH_espectrum_full_no_zcor.{}".format(save_dir,save_ftype), bbox_inches='tight')
# Out:
# Text(2.0, 500, '$^{208}$Tl photopeak')

# %% [markdown]
# ## C.3: Fit individual peaks

# %% [markdown]
# ### Cs peak: 662 keV

# %%
cuts_energy = C_basic & (A_rmax < cwide_rmax) & (A_zmin > cwide_zmin) & (A_zmax < cwide_zmax) & \
              (A_zlen > 8) & (A_zlen < 32) & (A_ntrks == 1)


fit_rng_low =0.64
fit_rng_high = 0.71

f = plt_spectrum(A_Eczlcorr, cuts_energy, 
              plt_rng_low = fit_rng_low,
              plt_rng_high = fit_rng_high,
              fit_rng_low = fit_rng_low,
              fit_rng_high = fit_rng_high,
              fit_gauss_A = 3500,
              fit_gauss_mu = 0.682,
              fit_gauss_sigma = 0.005,
              text_x = 1.002*0.640,
              nbins = 90,
              outfile_name = "CSTH_espectrum_Cs_fit_no_zcorr")

cuts_xyz = C_basic & (A_Eczlcorr > fit_rng_low) & (A_Eczlcorr < fit_rng_high)
plt_xyz_distributions(A_xavg, A_yavg, A_zavg, cuts_xyz, 
                      nxybins = 25, 
                      nzbins = 25, 
                      zmin = cwide_zmin, 
                      zmax = cwide_zmax, 
                      rmax = cwide_rmax,
                      outfile_name = "CSTH_xyzdist_Cs")

    
# Save relevant values for later use.
mu_cs_fid, e_mu_cs_fid, sigma_cs_fid, e_sigma_cs_fid = f.values[1], f.errors[1], f.values[2], f.errors[2]
# Out:
# Fit parameters are (amp, mu, sigma, A, mean, x0)
# [ 2.06071372e+01  6.84236473e-01  3.43319948e-03 -1.51464147e+04
#   5.07189903e+04 -4.11913312e+04]
# Fit errors are (amp, mu, sigma)
# [1.59572794e-01 2.63466409e-05 2.46019469e-05 2.79250565e+03
#  8.24915808e+03 6.08522185e+03]
# Fit p-value assuming obtained chi2 and 1 d.o.f. is 0.0927426100986476
# Fit range: (0.64,0.71)
# Fit range from mu in sigma: (-12.884911870698533,7.504232514456533)
# Resolution is 1.1791272623129139 +/- 0.0084496241016116
# Resolution at Qbb is 0.36739571097324353 +/- 0.002632757085252111

# %% [markdown]
# ### 208Tl double-escape peak: 1592 keV

# %%
cuts_energy = C_basic & (A_rmax < cwide_rmax) & (A_zmin > cwide_zmin) & (A_zmax < cwide_zmax) & \
              (A_zlen > 24) & (A_zlen < 72) & (A_ntrks == 1)


fit_rng_low = 1.6
fit_rng_high = 1.758

f = plt_spectrum(A_Eczlcorr, cuts_energy, 
              plt_rng_low = fit_rng_low,
              plt_rng_high = fit_rng_high,
              fit_rng_low = fit_rng_low,
              fit_rng_high = fit_rng_high,
              fit_gauss_A = 100,
              fit_gauss_mu = 1.62,
              fit_gauss_sigma = 0.1,
              text_x = 1.002*1.58,
              nbins = 90,
              outfile_name = "CSTH_espectrum_DE_fit_no_zcorr")

cuts_xyz = C_basic & (A_Eczlcorr > fit_rng_low) & (A_Eczlcorr < fit_rng_high)
plt_xyz_distributions(A_xavg, A_yavg, A_zavg, cuts_xyz, 
                      nxybins = 25, 
                      nzbins = 25, 
                      zmin = cwide_zmin, 
                      zmax = cwide_zmax, 
                      rmax = cwide_rmax,
                      outfile_name = "CSTH_xyzdist_DE")

    
# Save relevant values for later use.
mu_de_fid, e_mu_de_fid, sigma_de_fid, e_sigma_de_fid = f.values[1], f.errors[1], f.values[2], f.errors[2]
# Out:
# Fit parameters are (amp, mu, sigma, A, mean, x0)
# [ 1.11048879e+01  1.67706944e+00  6.84217912e-03 -1.93873154e+02
#   4.21877099e+02 -1.62590748e+02]
# Fit errors are (amp, mu, sigma)
# [1.67427451e-01 1.03513126e-04 9.49321238e-05 1.52544220e+03
#  1.81794684e+03 5.41157302e+02]
# Fit p-value assuming obtained chi2 and 1 d.o.f. is 0.23973043149745676
# Fit range: (1.6,1.758)
# Fit range from mu in sigma: (-11.263873724291402,11.828184691012584)
# Resolution is 0.958762979050061 +/- 0.013302531960937398
# Resolution at Qbb is 0.298734002343374 +/- 0.004144839445019899

# %% [markdown]
# ### 208Tl photopeak: 2.614 keV
# Note: if there are low statistics on this peak, one may have to select carefully the fit range.  In this case, the range selected before calibration may not give a correct fit afterward.  It may be helpful to remove the use of the `StoE` function after calibration, or it will be difficult to tell how what range is actually being selected.

# %%
cuts_energy = C_basic & (A_rmax < cwide_rmax) & (A_zmin > cwide_zmin) & (A_zmax < cwide_zmax) & \
              (A_zlen > 35) & (A_zlen < 130) & (A_ntrks == 1)
    
fit_rng_low = 2.74
fit_rng_high = 2.83

f = plt_spectrum(A_Eczlcorr, cuts_energy, 
              plt_rng_low = fit_rng_low,
              plt_rng_high = fit_rng_high,
              fit_rng_low = fit_rng_low,
              fit_rng_high = fit_rng_high,
              fit_gauss_A = 30,
              fit_gauss_mu = 2.78, 
              fit_gauss_sigma = 0.022,
              text_x = 1.002*2.66,
              nbins = 22,
              outfile_name = "CSTH_espectrum_Tl_fit_no_zcorr")

cuts_xyz = C_basic & (A_Eczlcorr > fit_rng_low) & (A_Eczlcorr < fit_rng_high)
plt_xyz_distributions(A_xavg, A_yavg, A_zavg, cuts_xyz, 
                      nxybins = 25, 
                      nzbins = 25, 
                      zmin = cwide_zmin, 
                      zmax = cwide_zmax, 
                      rmax = cwide_rmax,
                      outfile_name = "CSTH_xyzdist_Tl")

# Save relevant values for later use.
mu_tl_fid, e_mu_tl_fid, sigma_tl_fid, e_sigma_tl_fid = f.values[1], f.errors[1], f.values[2], f.errors[2]
# Out:
# Fit parameters are (amp, mu, sigma, A, mean, x0)
# [ 1.76695383e+00  2.78883205e+00  1.40447083e-02  2.10667737e+04
#  -1.50925392e+04  2.70267492e+03]
# Fit errors are (amp, mu, sigma)
# [4.10186035e-01 7.82645036e-04 1.73911979e-03 2.95668862e+04
#  2.12172301e+04 3.80548976e+03]
# Fit p-value assuming obtained chi2 and 1 d.o.f. is 0.5242082072755814
# Fit range: (2.74,2.83)
# Fit range from mu in sigma: (-3.476900437632503,2.9312070346933985)
# Resolution is 1.1834726441390477 +/- 0.14654672401332308
# Resolution at Qbb is 0.3687496569776223 +/- 0.04566143077216583

# %% [markdown]
# ----

# %% [markdown]
# ## Section D: Energy calibration
#
# **Relevant fit points**
# - $^{137}$Cs gamma, photopeak: 661.657 keV
# - $^{208}$Tl gamma, double-escape peak: 1592.535 keV
# - $^{208}$Tl gamma, photopeak: 2614.533 keV

# %% [markdown]
# ## D.1: Definitions

# %%
# A 2nd order polynomial
def poly2(x, a, b, c):
    return a*x**2 + b*x + c

# %%
# Calibrated (tabulated) energies.
mu_cal = np.array([E_Cs, E_descape, E_Tl])/1000
sigma_cal = np.array([err_E_Cs, err_E_descape, err_E_Tl])/1000

# Uncalibrated energies.
mu_uncal = np.array([mu_cs_fid, mu_de_fid, mu_tl_fid])
sigma_uncal = np.array([e_mu_cs_fid, e_mu_de_fid, e_mu_tl_fid])
print("mu_uncal = ", mu_uncal)
print("sigma_uncal = ", sigma_uncal)
print("sigma_uncal/mu_uncal*100 = ", sigma_uncal/mu_uncal*100)
# Out:
# mu_uncal =  [0.68423647 1.67706944 2.78883205]
# sigma_uncal =  [2.63466409e-05 1.03513126e-04 7.82645036e-04]
# sigma_uncal/mu_uncal*100 =  [0.00385052 0.00617226 0.02806354]

# %% [markdown]
# ## D.2: Quadratic fit

# %%
p, V = curve_fit(poly2, mu_uncal, mu_cal, sigma=sigma_cal, absolute_sigma=True)
a = p[0]
b = p[1]
c = p[2]
print("Fit parameters are: a = {}, b = {}, c = {}".format(a, b, c))

xfit = np.arange(0,3.0,0.01)
pfit = np.poly1d([a, b, c])
sigma_E  = np.array([0, 0, 0])

xres = xfit
res = 100*(mu_cal-pfit(mu_uncal))/mu_cal
res_err = 100*sigma_E/mu_cal
print("Residuals (%): {}".format(res))

fig = plt.figure()
fig.set_figheight(6.0)
fig.set_figwidth(15.0)
gs = gridspec.GridSpec(2, 1, height_ratios=[1,1]) 

ax1 = fig.add_subplot(gs[0])
ax1.plot(xfit, pfit(xfit), '--', color='gray')
ax1.plot(mu_uncal, mu_cal, '.', markerfacecolor='none', markersize=12, color='red')
#ax1.errorbar(mu_uncal, mu_cal, xerr=sigma_uncal, markersize=8, color='red', fmt='.')
ax1.set_ylabel('Nominal energy\n$E_0$ (keV)')
ax1.set_xlim(0,3.0)
#ax1.set_ylim(-0.02,1.02)

ax2 = fig.add_subplot(gs[1])
#ax2.errorbar(mu_uncal, res, yerr=res_err, capsize=5, fmt='.', markersize=6, color='red')
ax2.plot(mu_uncal, res, '.', markersize=6, color='red')
ax2.hlines(0.0,xmin=0.0,xmax=3.0,linestyle='--',color='gray',alpha=0.4)
ax2.set_xlabel('Raw energy, $Q$ (photoelectrons)')
ax2.set_ylabel('Residual (%)')
ax2.set_xlim(0,3.0)
ax2.set_ylim(-0.4,0.4)

CAL_a, CAL_b, CAL_c = a, b, c
#plt.savefig("{}/CSTH_energy_calibration.{}".format(save_dir,save_ftype), bbox_inches='tight')
# Out:
# Fit parameters are: a = -0.008713598014279067, b = 0.9581732631173085, c = 0.010119434519535328
# Residuals (%): [0.00000000e+00 1.39428399e-14 0.00000000e+00]

# %% [markdown]
# # Section C*: CALIBRATED Energy peaks

# %% [markdown]
# ## C.4: Full CALIBRATED energy spectrum

# %%
A_Ecal = CAL_a*A_Eczlcorr**2 + CAL_b*A_Eczlcorr + CAL_c

cuts_fullspectrum = C_wide & (A_ntrks == 1)

fig = plt.figure(1)
fig.patch.set_alpha(0.0)
fig.set_figheight(4.0)
fig.set_figwidth(12.0)

y, x, _ = plt.hist(A_Ecal[cuts_fullspectrum], 1000, range=[0.01,3.0], **hargs)
plt.xlabel('E (keV)')
plt.ylabel('Counts/bin')
plt.yscale('log')
plt.annotate('$^{137}$Cs photopeak', xy=(0.70, 10000),  xycoords='data',
                 xytext=(0.90, 12000), textcoords='data', fontsize=16,
                 arrowprops=dict(arrowstyle="-"))
plt.annotate('$^{208}$Tl e$^{+}$e$^{-}$ double-escape', xy=(1.69, 1500),  xycoords='data',
                 xytext=(1.9, 10000), textcoords='data', fontsize=16,
                 arrowprops=dict(arrowstyle="-"))
plt.annotate('$^{208}$Tl photopeak', xy=(2.7, 60),  xycoords='data',
                xytext=(2.0, 500), textcoords='data', fontsize=16,
                arrowprops=dict(arrowstyle="-"))

#plt.savefig("{}/CSTH_espectrum_full.{}".format(save_dir,save_ftype), bbox_inches='tight')
# Out:
# Text(2.0, 500, '$^{208}$Tl photopeak')

# %% [markdown]
# ## C.5: Fit CALIBRATED individual peaks

# %% [markdown]
# ### Cs peak: 662 keV

# %%
cuts_energy = C_basic & (A_rmax < cwide_rmax) & (A_zmin > cwide_zmin) & (A_zmax < cwide_zmax) & \
              (A_zlen > 8) & (A_zlen < 32) & (A_ntrks == 1)


fit_rng_low =0.64
fit_rng_high = 0.68

f = plt_spectrum(A_Ecal, cuts_energy, 
              plt_rng_low = fit_rng_low,
              plt_rng_high = fit_rng_high,
              fit_rng_low = fit_rng_low,
              fit_rng_high = fit_rng_high,
              fit_gauss_A = 3500,
              fit_gauss_mu = 0.66,
              fit_gauss_sigma = 0.005,
              text_x = 1.002*0.640,
              nbins = 90,
              outfile_name = "CSTH_espectrum_Cs_fit_zcorrected")

cuts_xyz = C_basic & (A_Ecal > fit_rng_low) & (A_Ecal < fit_rng_high)
plt_xyz_distributions(A_xavg, A_yavg, A_zavg, cuts_xyz, 
                      nxybins = 25, 
                      nzbins = 25, 
                      zmin = cwide_zmin, 
                      zmax = cwide_zmax, 
                      rmax = cwide_rmax,
                      outfile_name = "CSTH_xyzdist_Cs_zcorrected")

    
# Save relevant values for later use.
mu_cs_fid, e_mu_cs_fid, sigma_cs_fid, e_sigma_cs_fid = f.values[1], f.errors[1], f.values[2], f.errors[2]
# Out:
# Fit parameters are (amp, mu, sigma, A, mean, x0)
# [ 1.19433849e+01  6.61681622e-01  3.28490793e-03  2.38406868e+03
#  -2.38367242e+03 -1.49047215e+03]
# Fit errors are (amp, mu, sigma)
# [1.15107938e-01 2.50268551e-05 2.73344532e-05 8.59733338e+03
#  2.60310423e+04 1.96943390e+04]
# Fit p-value assuming obtained chi2 and 1 d.o.f. is 0.23064457102437919
# Fit range: (0.64,0.68)
# Fit range from mu in sigma: (-6.600374471495393,5.576526946234418)
# Resolution is 1.166653775484827 +/- 0.009708087155930741
# Resolution at Qbb is 0.36350918768776613 +/- 0.003024872460201725

# %% [markdown]
# ### 208Tl double-escape peak: 1592 keV

# %%
cuts_energy = C_basic & (A_rmax < cwide_rmax) & (A_zmin > cwide_zmin) & (A_zmax < cwide_zmax) & \
              (A_zlen > 24) & (A_zlen < 72) & (A_ntrks == 1)


fit_rng_low = 1.56
fit_rng_high = 1.623

f = plt_spectrum(A_Ecal, cuts_energy, 
              plt_rng_low = fit_rng_low,
              plt_rng_high = fit_rng_high,
              fit_rng_low = fit_rng_low,
              fit_rng_high = fit_rng_high,
              fit_gauss_A = 600,
              fit_gauss_mu = 1.59,
              fit_gauss_sigma = 0.05,
              text_x = 1.002*fit_rng_low,
              nbins = 90,
              outfile_name = "CSTH_espectrum_DE_fit_zcorrected")

cuts_xyz = C_basic & (A_Ecal > fit_rng_low) & (A_Ecal < fit_rng_high)
plt_xyz_distributions(A_xavg, A_yavg, A_zavg, cuts_xyz, 
                      nxybins = 25, 
                      nzbins = 25, 
                      zmin = cwide_zmin, 
                      zmax = cwide_zmax, 
                      rmax = cwide_rmax,
                      outfile_name = "CSTH_xyzdist_DE_zcorrected")

    
# Save relevant values for later use.
mu_de_fid, e_mu_de_fid, sigma_de_fid, e_sigma_de_fid = f.values[1], f.errors[1], f.values[2], f.errors[2]
# Out:
# Fit parameters are (amp, mu, sigma, A, mean, x0)
# [ 4.42848082e+00  1.59247637e+00  6.29636587e-03  5.37642350e+03
#  -6.70815763e+03  2.10149654e+03]
# Fit errors are (amp, mu, sigma)
# [1.04791190e-01 9.74158801e-05 1.19937405e-04 1.05015702e+04
#  1.31963921e+04 4.14466824e+03]
# Fit p-value assuming obtained chi2 and 1 d.o.f. is 0.26607923898448316
# Fit range: (1.56,1.623)
# Fit range from mu in sigma: (-5.157954195031196,4.847817599401938)
# Resolution is 0.9291478414772933 +/- 0.01769912322782228
# Resolution at Qbb is 0.28950643643774404 +/- 0.005514741427599336

# %% [markdown]
# ### 208Tl photopeak: 2.614 keV

# %%
cuts_energy = C_basic & (A_rmax < cwide_rmax) & (A_zmin > cwide_zmin) & (A_zmax < cwide_zmax) & \
              (A_zlen > 35) & (A_zlen < 130) & (A_ntrks == 1)
    
fit_rng_low = 2.57
fit_rng_high = 2.65

f = plt_spectrum(A_Ecal, cuts_energy, 
              plt_rng_low = fit_rng_low,
              plt_rng_high = fit_rng_high,
              fit_rng_low = fit_rng_low,
              fit_rng_high = fit_rng_high,
              fit_gauss_A = 30,
              fit_gauss_mu = 2.614, 
              fit_gauss_sigma = 0.01,
              text_x = 1.002*2.66,
              nbins = 22,
              outfile_name = "CSTH_espectrum_Tl_fit_zcorrected")

cuts_xyz = C_basic & (A_Ecal > fit_rng_low) & (A_Ecal < fit_rng_high)
plt_xyz_distributions(A_xavg, A_yavg, A_zavg, cuts_xyz, 
                      nxybins = 25, 
                      nzbins = 25, 
                      zmin = cwide_zmin, 
                      zmax = cwide_zmax, 
                      rmax = cwide_rmax,
                      outfile_name = "CSTH_xyzdist_Tl_zcorrected")

# Save relevant values for later use.
mu_tl_fid, e_mu_tl_fid, sigma_tl_fid, e_sigma_tl_fid = f.values[1], f.errors[1], f.values[2], f.errors[2]
# Out:
# Fit parameters are (amp, mu, sigma, A, mean, x0)
# [ 1.51380560e+00  2.61449110e+00  1.27410361e-02  1.84051180e+04
#  -1.40653138e+04  2.68683354e+03]
# Fit errors are (amp, mu, sigma)
# [3.73817166e-01 7.70207931e-04 1.65136435e-03 3.22416846e+04
#  2.46814697e+04 4.72248674e+03]
# Fit p-value assuming obtained chi2 and 1 d.o.f. is 0.46341795166255284
# Fit range: (2.57,2.65)
# Fit range from mu in sigma: (-3.4919529192529475,2.786971276674129)
# Resolution is 1.1452108179274783 +/- 0.1484310372862412
# Resolution at Qbb is 0.3568279320769866 +/- 0.04624855027718187

# %% [markdown]
# ---

# %% [markdown]
# # Section E: Misc.

# %% [markdown]
# ## E.1: Energy vs. time

# %%
# Energy vs. time
cuts_T = C_wide

nbins = 8

print(A_time[0])
print(A_time[-1])

# for double-escape peak
Thist_min_D = A_time[0] #1531175.7
Thist_max_D = A_time[-1] #1531210.6
Ehist_min_D = 1.50
Ehist_max_D = 1.67
plt_rng_Tlow_D = A_time[0]
plt_rng_Thigh_D = A_time[-1]
plt_rng_Elow_D = 1.50
plt_rng_Ehigh_D = 1.67

# for Cs peak
Thist_min_Cs = A_time[0]
Thist_max_Cs = A_time[-1]
Ehist_min_Cs = 0.63
Ehist_max_Cs = 0.69
plt_rng_Tlow_Cs = A_time[0]
plt_rng_Thigh_Cs = A_time[-1]
plt_rng_Elow_Cs = 0.63
plt_rng_Ehigh_Cs = 0.69

fig = plt.figure()
fig.patch.set_alpha(0.0)
fig.set_figheight(6.0)
fig.set_figwidth(15.0)

ax1 = fig.add_subplot(121);
ax1.scatter(A_time[cuts_T],A_Ecal[cuts_T],s=0.5)
#ax1.axhline(y=Ehist_min_D,c="red",linewidth=1.2,linestyle='dashed')
#ax1.axhline(y=Ehist_max_D,c="red",linewidth=1.2,linestyle='dashed')
plt.title("Energy vs. T")
plt.ylim([plt_rng_Elow_D,plt_rng_Ehigh_D])
plt.xlim([plt_rng_Tlow_D,plt_rng_Thigh_D])
plt.xlabel('T')
plt.ylabel('E (keV)')

ax5 = fig.add_subplot(122);
ax5.scatter(A_time[cuts_T],A_Ecal[cuts_T],s=0.5)
#ax5.axhline(y=Ehist_min_Cs,c="red",linewidth=1.2,linestyle='dashed')
#ax5.axhline(y=Ehist_max_Cs,c="red",linewidth=1.2,linestyle='dashed')
plt.title("Energy vs. T")
plt.ylim([plt_rng_Elow_Cs,plt_rng_Ehigh_Cs])
plt.xlim([plt_rng_Tlow_Cs,plt_rng_Thigh_Cs])
plt.xlabel('T')
plt.ylabel('E (keV)')

#plt.savefig("{}/CSTH_E_vs_T.{}".format(save_dir,save_ftype), bbox_inches='tight')
# Out:
# 1565275939328.0
# 1565780924982.0
# Text(0, 0.5, 'E (keV)')
